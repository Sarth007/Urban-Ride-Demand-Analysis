# %%
# !mkdir Project1_RideDataAnalysis
# !mkdir Project1_RideDataAnalysis/data
# !mkdir Project1_RideDataAnalysis/visuals
# !mkdir Project1_RideDataAnalysis/report

# %%
# !ls Project1_RideDataAnalysis
# Out:
# data  report  visuals

# %%
# !ls Project1_RideDataAnalysis/data

# %%
import pandas as pd

df = pd.read_csv("Project1_RideDataAnalysis/data/rideshare_kaggle.csv")
df.head()
# Out:
#                                      id     timestamp  hour  day  month  \
# 0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7  1.544953e+09     9   16     12
# 1  4bd23055-6827-41c6-b23b-3c491f24e74d  1.543284e+09     2   27     11
# 2  981a3613-77af-4620-a42a-0c0866077d1e  1.543367e+09     1   28     11
# 3  c2d88af2-d278-4bfd-a8d0-29ca77cc5512  1.543554e+09     4   30     11
# 4  e0126e1f-8ca9-4f2e-82b3-50505a09db9a  1.543463e+09     3   29     11
#
#               datetime          timezone            source    destination  \
# 0  2018-12-16 09:30:07  America/New_York  Haymarket Square  North Station
# 1  2018-11-27 02:00:23  America/New_York  Haymarket Square  North Station
# 2  2018-11-28 01:00:22  America/New_York  Haymarket Square  North Station
# 3  2018-11-30 04:53:02  America/New_York  Haymarket Square  North Station
# 4  2018-11-29 03:49:20  America/New_York  Haymarket Square  North Station
#
#   cab_type  ... precipIntensityMax   uvIndexTime  temperatureMin  \
# ...

# %%
df.shape
# Out:
# (3930, 57)

# %%
df.columns
# Out:
# Index(['id', 'timestamp', 'hour', 'day', 'month', 'datetime', 'timezone',
#        'source', 'destination', 'cab_type', 'product_id', 'name', 'price',
#        'distance', 'surge_multiplier', 'latitude', 'longitude', 'temperature',
#        'apparentTemperature', 'short_summary', 'long_summary',
#        'precipIntensity', 'precipProbability', 'humidity', 'windSpeed',
#        'windGust', 'windGustTime', 'visibility', 'temperatureHigh',
#        'temperatureHighTime', 'temperatureLow', 'temperatureLowTime',
#        'apparentTemperatureHigh', 'apparentTemperatureHighTime',
#        'apparentTemperatureLow', 'apparentTemperatureLowTime', 'icon',
#        'dewPoint', 'pressure', 'windBearing', 'cloudCover', 'uvIndex',
#        'visibility.1', 'ozone', 'sunriseTime', 'sunsetTime', 'moonPhase',
#        'precipIntensityMax', 'uvIndexTime', 'temperatureMin',
#        'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3930 entries, 0 to 3929
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           3930 non-null   object
#  1   timestamp                    3930 non-null   float64
#  2   hour                         3929 non-null   float64
#  3   day                          3929 non-null   float64
#  4   month                        3929 non-null   float64
#  5   datetime                     3929 non-null   object
#  6   timezone                     3929 non-null   object
#  7   source                       3929 non-null   object
#  8   destination                  3929 non-null   object
#  9   cab_type                     3929 non-null   object
#  10  product_id                   3929 non-null   object
#  11  name                         3929 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# id                               0
# timestamp                        0
# hour                             1
# day                              1
# month                            1
# datetime                         1
# timezone                         1
# source                           1
# destination                      1
# cab_type                         1
# product_id                       1
# name                             1
# price                          303
# distance                         1
# surge_multiplier                 1
# latitude                         1
# longitude                        1
# temperature                      1
# apparentTemperature              1
# short_summary                    1
# long_summary                     1
# precipIntensity                  1
# precipProbability                1
# humidity                         1
# windSpeed                        1
# windGust                         1
# windGustTime                     1
# ...

# %% [markdown]
# Dataset Overview
# The dataset contains ride-level information including cab type, pickup and drop locations, timestamps, and pricing. Initial inspection shows missing values in price-related fields, which will be handled during data cleaning.

# %%
df.isnull().sum()
# Out:
# id                             0
# timestamp                      0
# hour                           0
# day                            0
# month                          0
# datetime                       0
# timezone                       0
# source                         0
# destination                    0
# cab_type                       0
# product_id                     0
# name                           0
# price                          0
# distance                       0
# surge_multiplier               0
# latitude                       0
# longitude                      0
# temperature                    0
# apparentTemperature            0
# short_summary                  0
# long_summary                   0
# precipIntensity                0
# precipProbability              0
# humidity                       0
# windSpeed                      0
# windGust                       1
# windGustTime                   1
# visibility                     1
# ...

# %%
df = df.dropna(subset=['price'])

# %%
df.isnull().sum()
# Out:
# id                             0
# timestamp                      0
# hour                           0
# day                            0
# month                          0
# datetime                       0
# timezone                       0
# source                         0
# destination                    0
# cab_type                       0
# product_id                     0
# name                           0
# price                          0
# distance                       0
# surge_multiplier               0
# latitude                       0
# longitude                      0
# temperature                    0
# apparentTemperature            0
# short_summary                  0
# long_summary                   0
# precipIntensity                0
# precipProbability              0
# humidity                       0
# windSpeed                      0
# windGust                       1
# windGustTime                   1
# visibility                     1
# ...

# %%
df['datetime'] = pd.to_datetime(df['timestamp'], unit='s')

# %%
df[['timestamp', 'datetime']].head()
# Out:
#       timestamp                      datetime
# 0  1.544953e+09 2018-12-16 09:30:07.890000105
# 1  1.543284e+09 2018-11-27 02:00:23.677000046
# 2  1.543367e+09 2018-11-28 01:00:22.197999954
# 3  1.543554e+09 2018-11-30 04:53:02.749000072
# 4  1.543463e+09 2018-11-29 03:49:20.223000050

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## Data Cleaning
#
# Rows with missing price values were removed as pricing is essential for demand and revenue analysis.
# The timestamp column was converted into datetime format to enable time-based analysis.
# Duplicate records were also removed to ensure data accuracy.

# %%
df['hour'] = df['datetime'].dt.hour
df[['datetime', 'hour']].head()
# Out:
#                        datetime  hour
# 0 2018-12-16 09:30:07.890000105     9
# 1 2018-11-27 02:00:23.677000046     2
# 2 2018-11-28 01:00:22.197999954     1
# 3 2018-11-30 04:53:02.749000072     4
# 4 2018-11-29 03:49:20.223000050     3

# %%
df['day'] = df['datetime'].dt.day_name()
df[['datetime', 'day']].head()
# Out:
#                        datetime        day
# 0 2018-12-16 09:30:07.890000105     Sunday
# 1 2018-11-27 02:00:23.677000046    Tuesday
# 2 2018-11-28 01:00:22.197999954  Wednesday
# 3 2018-11-30 04:53:02.749000072     Friday
# 4 2018-11-29 03:49:20.223000050   Thursday

# %%
def peak_hour(hour):
    if (7 <= hour <= 9) or (17 <= hour <= 20):
        return 'Peak'
    else:
        return 'Non-Peak'

df['peak_status'] = df['hour'].apply(peak_hour)
df[['hour', 'peak_status']].head()
# Out:
#    hour peak_status
# 0     9        Peak
# 1     2    Non-Peak
# 2     1    Non-Peak
# 3     4    Non-Peak
# 4     3    Non-Peak

# %% [markdown]
# ## Feature Engineering
#
# New time-based features were created to support exploratory analysis.
# Hour and day columns were extracted from the datetime field to study temporal demand patterns.
# Additionally, rides were classified into peak and non-peak hours based on standard commute timings.

# %%
hourly_demand = df.groupby('hour').size()
hourly_demand
# Out:
# hour
# 0     661
# 1     609
# 2     628
# 3     553
# 4     637
# 5     526
# 6     585
# 7     521
# 8     532
# 9     590
# 10    615
# 11    605
# 12    647
# 13    635
# 14    632
# 15    636
# 16    685
# 17    619
# 18    602
# 19    562
# 20    585
# 21    572
# 22    617
# 23    691
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(hourly_demand.index, hourly_demand.values, marker='o')
plt.title("Ride Demand by Hour of Day")
plt.xlabel("Hour of Day")
plt.ylabel("Number of Rides")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(hourly_demand.index, hourly_demand.values, marker='o')
plt.title("Ride Demand by Hour of Day")
plt.xlabel("Hour of Day")
plt.ylabel("Number of Rides")
plt.grid(True)
plt.savefig("Project1_RideDataAnalysis/visuals/ride_demand_by_hour.png")
plt.show()

# %% [markdown]
# ## Ride Demand by Hour
#
# The hourly demand analysis shows clear variations in ride usage throughout the day.
# Demand is lowest during late-night hours and increases significantly during morning and evening periods, indicating strong commuter-driven usage patterns.

# %%
df['price'].describe()
# Out:
# count    14545.000000
# mean        16.390856
# std          9.187501
# min          2.500000
# 25%          9.000000
# 50%         13.500000
# 75%         22.500000
# max         80.000000
# Name: price, dtype: float64

# %%
avg_price_hour = df.groupby('hour')['price'].mean()
avg_price_hour
# Out:
# hour
# 0     16.755673
# 1     16.385878
# 2     16.178344
# 3     16.594937
# 4     16.562794
# 5     16.064639
# 6     16.623932
# 7     17.222649
# 8     16.101504
# 9     16.890678
# 10    16.071545
# 11    15.945455
# 12    15.995363
# 13    15.823622
# 14    16.677215
# 15    15.374214
# 16    16.494161
# 17    16.859451
# 18    16.827243
# 19    16.238434
# 20    16.545299
# 21    16.484266
# 22    16.519449
# 23    16.275687
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(avg_price_hour.index, avg_price_hour.values, marker='o')
plt.title("Average Ride Price by Hour")
plt.xlabel("Hour of Day")
plt.ylabel("Average Price")
plt.grid(True)
plt.savefig("Project1_RideDataAnalysis/visuals/avg_ride_by_hours.png")
plt.show()

# %%
df.groupby('peak_status')['price'].mean()
# Out:
# peak_status
# Non-Peak    16.283416
# Peak        16.673024
# Name: price, dtype: float64

# %%
import seaborn as sns

plt.figure(figsize=(6,5))
sns.boxplot(x='peak_status', y='price', data=df)
plt.title("Price Distribution: Peak vs Non-Peak Hours")
plt.savefig("Project1_RideDataAnalysis/visuals/Peak_vs_Non-Peak_Hours.png")
plt.show()

# %% [markdown]
# ## Price Analysis
#
# The pricing analysis indicates noticeable variation in ride fares across different times of the day.
# Average prices are significantly higher during peak hours compared to non-peak periods, suggesting the presence of surge pricing mechanisms.
# This trend highlights the strong relationship between ride demand and pricing.

# %%
df.columns
# Out:
# Index(['id', 'timestamp', 'hour', 'day', 'month', 'datetime', 'timezone',
#        'source', 'destination', 'cab_type', 'product_id', 'name', 'price',
#        'distance', 'surge_multiplier', 'latitude', 'longitude', 'temperature',
#        'apparentTemperature', 'short_summary', 'long_summary',
#        'precipIntensity', 'precipProbability', 'humidity', 'windSpeed',
#        'windGust', 'windGustTime', 'visibility', 'temperatureHigh',
#        'temperatureHighTime', 'temperatureLow', 'temperatureLowTime',
#        'apparentTemperatureHigh', 'apparentTemperatureHighTime',
#        'apparentTemperatureLow', 'apparentTemperatureLowTime', 'icon',
#        'dewPoint', 'pressure', 'windBearing', 'cloudCover', 'uvIndex',
#        'visibility.1', 'ozone', 'sunriseTime', 'sunsetTime', 'moonPhase',
#        'precipIntensityMax', 'uvIndexTime', 'temperatureMin',
#        'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime',
# ...

# %%
location_demand = df.groupby('source').size().sort_values(ascending=False)
location_demand.head(10)
# Out:
# source
# Theatre District           1321
# North Station              1321
# West End                   1260
# Financial District         1258
# Fenway                     1238
# North End                  1229
# Haymarket Square           1216
# Beacon Hill                1215
# Back Bay                   1165
# Northeastern University    1134
# dtype: int64

# %%
import matplotlib.pyplot as plt

top_locations = location_demand.head(10)

plt.figure(figsize=(10,5))
top_locations.plot(kind='bar')
plt.title("Top 10 Pickup Locations by Ride Demand")
plt.xlabel("Pickup Location")
plt.ylabel("Number of Rides")
plt.xticks(rotation=45)
plt.savefig("Project1_RideDataAnalysis/visuals/top_pickup_locations.png")
plt.show()

# %% [markdown]
# ## Demand by Location
#
# The location-based analysis highlights significant variation in ride demand across different pickup points.
# Certain central and high-traffic locations consistently generate higher ride volumes, indicating demand hotspots.
# These insights can help ride-sharing platforms optimize driver allocation and dynamic pricing strategies.

# %% [markdown]
# 📊 Key Data-Driven Insights
#
# Ride demand follows a strong daily pattern, with clear peaks during morning (7–9 AM) and evening (5–8 PM) hours, indicating that ride usage is highly influenced by office commute schedules.
#
# Late-night and early-morning hours show significantly lower ride demand, suggesting reduced user activity but potential opportunities for premium pricing due to limited driver availability.
#
# Average ride prices are noticeably higher during peak hours compared to non-peak periods, confirming the impact of surge pricing mechanisms during high-demand times.
#
# Non-peak hours offer more cost-effective rides, making them ideal for price-sensitive users and suitable for promotional or discount-based strategies.
#
# Certain pickup locations consistently generate higher ride volumes, highlighting demand hotspots such as central business areas and high-traffic zones.
#
# Location-based demand varies significantly, indicating that ride-sharing platforms can optimize driver distribution by focusing on high-demand pickup areas.
#
# Price variation closely correlates with demand trends, reinforcing the relationship between user activity levels and dynamic pricing strategies.
#
# Overall ride behavior suggests predictable usage patterns, which can be leveraged for better fleet management, reduced passenger wait times, and increased operational efficiency.

# %% [markdown]
# ## Business-Friendly Summary Report
#
# This project analyzes urban ride usage and pricing patterns using real-world ride-sharing data.
# The objective was to understand how ride demand and pricing vary across time and location to support better operational and business decisions.
#
# The analysis shows that ride demand follows a predictable daily pattern, with significant peaks during morning and evening commute hours.
# These peak periods align with typical office travel times, indicating commuter-driven usage.
# In contrast, late-night and early-morning hours experience lower demand.
#
# Pricing analysis reveals that average ride prices are higher during peak hours, suggesting the use of surge pricing mechanisms to balance supply and demand.
# Non-peak hours offer more affordable rides, which can be leveraged for promotional strategies targeting price-sensitive customers.
#
# Location-based analysis highlights that certain pickup areas consistently generate higher ride volumes.
# These demand hotspots can help ride-sharing platforms strategically position drivers to reduce wait times and improve service efficiency.
#
# Overall, the findings suggest that optimizing driver availability during peak hours and high-demand locations can significantly improve revenue, customer satisfaction, and operational efficiency.

# %% [markdown]
# ## Business-Friendly Summary Report
#
# This project analyzes urban ride usage and pricing patterns using real-world ride-sharing data to understand customer behavior and demand trends.
#
# The analysis reveals that ride demand follows a predictable daily pattern, with significant peaks during morning and evening commute hours. These periods align with office travel times, indicating that commuter behavior strongly influences ride usage.
#
# Pricing analysis shows that average ride prices are higher during peak hours compared to non-peak periods, highlighting the impact of surge pricing mechanisms used to balance supply and demand. Non-peak hours offer more affordable rides, making them suitable for promotional strategies.
#
# Location-based demand analysis identifies specific pickup areas that consistently generate higher ride volumes. These demand hotspots represent opportunities for better driver positioning and improved service efficiency.
#
# Overall, the findings suggest that optimizing driver availability during peak hours and high-demand locations can increase revenue, reduce passenger wait times, and improve overall operational efficiency for ride-sharing platforms.

# %%
# !ls Project1_RideDataAnalysis
# Out:
# data  report  visuals

# %%
# !ls Project1_RideDataAnalysis/data
# Out:
# rideshare_kaggle.csv

# %%
# !rm Project1_RideDataAnalysis/data/rideshare_kaggle.csv

# %%
# !ls Project1_RideDataAnalysis/data

# %%
# !zip -r Project1_RideDataAnalysis.zip Project1_RideDataAnalysis
# Out:
#   adding: Project1_RideDataAnalysis/ (stored 0%)
#   adding: Project1_RideDataAnalysis/visuals/ (stored 0%)
#   adding: Project1_RideDataAnalysis/visuals/top_pickup_locations.png (deflated 18%)
#   adding: Project1_RideDataAnalysis/visuals/avg_ride_by_hours.png (deflated 6%)
#   adding: Project1_RideDataAnalysis/visuals/Peak_vs_Non-Peak_Hours.png (deflated 16%)
#   adding: Project1_RideDataAnalysis/visuals/ride_demand_by_hour.png (deflated 6%)
#   adding: Project1_RideDataAnalysis/report/ (stored 0%)
#   adding: Project1_RideDataAnalysis/data/ (stored 0%)

# %%
from google.colab import files
files.download("Project1_RideDataAnalysis.zip")
